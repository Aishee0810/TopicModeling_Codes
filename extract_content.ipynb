# %%
# !pip install docx2txt
# Out:
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-cp36-none-any.whl size=3963 sha256=10e55a46baf66a8e65946fec4011a40c49ea9e3170b8f0e16f7f1a9ed7942842
#   Stored in directory: /root/.cache/pip/wheels/b2/1f/26/a051209bbb77fc6bcfae2bb7e01fa0ff941b82292ab084d596
# Successfully built docx2txt
# ...

# %%
import docx2txt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#my_text = docx2txt.process("/content/drive/My Drive/1_joint_forum.docx")
#my_text = docx2txt.process("/content/drive/My Drive/Topic Modeling/Dataset/2_no nrc movement.docx")
# my_text = docx2txt.process("/content/drive/My Drive/Topic Modeling/Dataset/3_student nrc.docx")
my_text = docx2txt.process("/content/drive/My Drive/Topic Modeling/Dataset/5_NoNRCmUMBAI.docx")
print(my_text)
# Out:
# POST 2513
#
#
#
# VM1252:42 post number0......................................................................
#
# VM1252:56 posterName 	Alam Gir	 postTime12/02/2020
#
# VM1252:65 posterLink 	https://www.facebook.com/alam.gir.71216
#
# VM1252:77 postContent 	Unavailable
#
# VM1252:86 ColouredPost 	Unavailable
#
# VM1252:96 sharedLink 	Unavailable
#
# VM1252:104 sharedLinkContent
#
# VM1252:113 SharedPostContent 	#ये_ग़लत_किया_केजरीवाल_ने_रिंकिया_के_पापा_को_रुलाकर 😂😂😂😂
#
# VM1252:123 postLike 	28
#
# VM1252:132 postComments 	5
#
# VM1252:141 postShare 	7
#
# POST 2514
#
#
#
# VM1252:42 post number1......................................................................
#
# VM1252:56 posterName 	MD Sarfaraz Ahmad Nadwi	 postTime12/02/2020
#
# VM1252:65 posterLink 	https://www.facebook.com/profile.php
#
# VM1252:77 postContent 	Unavailable
#
# VM1252:86 ColouredPost 	Unavailable
#
# VM1252:96 sharedLink 	Unavailable
#
# VM1252:104 sharedLinkContent
#
# ...

# %%
text=my_text.splitlines()
while('' in text):
  text.remove('')
text
# Out:
# ['POST 2513',
#  'VM1252:42 post number0......................................................................',
#  'VM1252:56 posterName \tAlam Gir\t postTime12/02/2020\t',
#  'VM1252:65 posterLink \thttps://www.facebook.com/alam.gir.71216\t',
#  'VM1252:77 postContent \tUnavailable\t',
#  'VM1252:86 ColouredPost \tUnavailable\t',
#  'VM1252:96 sharedLink \tUnavailable\t',
#  'VM1252:104 sharedLinkContent \t\t',
#  'VM1252:113 SharedPostContent \t#ये_ग़लत_किया_केजरीवाल_ने_रिंकिया_के_पापा_को_रुलाकर 😂😂😂😂\t',
#  'VM1252:123 postLike \t28\t',
#  'VM1252:132 postComments \t5\t',
#  'VM1252:141 postShare \t7\t',
#  'POST 2514',
#  'VM1252:42 post number1......................................................................',
#  'VM1252:56 posterName \tMD Sarfaraz Ahmad Nadwi\t postTime12/02/2020\t',
#  'VM1252:65 posterLink \thttps://www.facebook.com/profile.php\t',
#  'VM1252:77 postContent \tUnavailable\t',
#  'VM1252:86 ColouredPost \tUnavailable\t',
# ...

# %%
# sharedPost=[x for x in text if x.startswith('VM508:113')]
#sharedPost=[x for x in text if x.startswith('VM740:113')]
# sharedPost=[x for x in text if x.startswith('VM513:113')]
sharedPost=[x for x in text if x.startswith('VM1252:113')]
# sharedPost=[x for x in text if x.startswith('VM1252:113')]
# sharedPost=[x for x in text if x.startswith('VM1252:113')]
# sharedPost=[x for x in text if x.startswith('VM1252:113')]

# %%
len(sharedPost)
# Out:
# 358

# %%
import re
remove2='\t'
#remove1='VM508:113 SharedPostContent'
# remove1='VM740:113 SharedPostContent'
# remove1='VM513:113 SharedPostContent'
remove1='VM1252:113 SharedPostContent'
# remove1='VM513:113 SharedPostContent'
# remove1='VM513:113 SharedPostContent'
# remove1='VM513:113 SharedPostContent'
# remove3='Unavailable'
s=[]
for x in sharedPost:
  x=re.sub(remove1,'',x)
  x=re.sub(remove2,'',x)
  s.append(x)

# %%
len(s)
# Out:
# 358

# %%
s[357]
# Out:
# ' Unavailable'

# %%
post_number=[y for y in text if (y.startswith('POST') or y.startswith(' POST'))]
len(post_number)
# Out:
# 357

# %%
remove='POST '
# remove3='Unavailable'
pn=[]
for x in post_number:
  x=re.sub(remove,'',x)
  pn.append(int(x))

# %%
len(pn)
pn[356]
# Out:
# 2869

# %%
for i in range(1,len(pn)):
  if pn[i]-pn[i-1]==1:
    print(pn[i])

# %%
for i in range(len(s)):
  print("post no.:",pn[i])
  print("Content: ",s[i])
# Out:
# post no.: 2513
# Content:   #ये_ग़लत_किया_केजरीवाल_ने_रिंकिया_के_पापा_को_रुलाकर 😂😂😂😂
# post no.: 2514
# Content:   #गोबरभकतो की #गोबरभविष्यवाणी 😂😂😂😂
# post no.: 2515
# Content:   Unavailable
# post no.: 2516
# Content:   अगर आपको इन दोनों नेताओं में से अच्छा प्रधानमंत्री चुनने का मौका मिले तो आप किसे चुनेंगे अरविंद केजरीवाल या नरेंद्र मोदी?
# post no.: 2517
# Content:   नई दिल्ली: मनोज तिवारी ने शाहीन बाग की महिलाओं को किया चैलेंज कहा अगर सही में CAA के विरोध में प्रदर्शन पर बैठे हैं तो 11 फरवरी के बाद बैठ के ‌दिखाओ।
# post no.: 2518
# Content:   यही है वो कुत्ता जिसने जामिया में लड़कियों के प्राइवेट पार्ट पर लात मारी इस कुत्ते पर FIR हो😠
# post no.: 2519
# Content:   Saharanpur, U.P - Nahid Zaidi, 40, who teaches English and Social Sciences at Asha Modern School, told news agency PTI she was also suspended from the school after she visited Shaheen Bagh on January 19
# post no.: 2520
# Content:   चुनाव कहीं भी हो लेकिन कुछ लोग बीजेपी की हार का इंतजार ऐसे करते हैं,
# post no.: 2521
# ...

# %%
#postContent=[a for a in text if a.startswith('VM508:77')]
# postContent=[a for a in text if a.startswith('VM740:77')]
postContent=[a for a in text if a.startswith('VM513:77')]
postContent
# Out:
# ['VM513:77 postContent \tUnavailable\t',
#  'VM513:77 postContent \tUnavailable\t',
#  'VM513:77 postContent \tআগামীকাল থেকে বইমেলায় পাওয়া যাবে ছাত্রছাত্রীদের উদ্যোগে প্রকাশিত পুস্তিকা *প্রশ্ন-উত্তরে: NRC-NPR-CAA*',
#  'VM513:77 postContent \tUnavailable\t',
#  'VM513:77 postContent \tVIRAL Anthem || Manzoor Nahi || Against CAA NRC NPR || LETS MAKE IT VIRAL\t',
#  'VM513:77 postContent \tUnavailable\t',
#  'VM513:77 postContent \tUnavailable\t',
#  'VM513:77 postContent \tUnavailable\t',
#  'VM513:77 postContent \tUnavailable\t',
#  'VM513:77 postContent \tUnavailable\t',
#  'VM513:77 postContent \tবইমেলায় দেখা হলো কমরেড Sumona Choudhuryর সঙ্গে। অসমের করিমগঞ্জের মেয়ে সুমনা। ওর তলোয়ারের মত ধারালো লেখনীর আমি একজন গুণমুগ্ধ পাঠক। অসমে বন্যার সময় #পদক্ষেপের টিম যখন বরপেটায় যায়, সেই সময় থেকেই আলাপ। ও তখন একটার পর একটা ক্ষুরধার লেখা লিখছে আসামে এনআরসি প্রক্রিয়া নিয়ে। আজ সামনাসামনি পেয়ে প্রশ্নে প্রশ্নে ব্যতিব্যস্ত করলাম। তার কিছু ঝলক ধরা রইলো এখানে।',
# ...

# %%
# rmove1='VM508:77 postContent'
# rmove1='VM740:77 postContent'
rmove1='VM513:77 postContent'
post_Content=[]
for x in postContent:
  x=re.sub(rmove1,'',x)
  x=re.sub(remove2,'',x)
  post_Content.append(x)

# %%
post_Content
# Out:
# [' Unavailable',
#  ' Unavailable',
#  ' আগামীকাল থেকে বইমেলায় পাওয়া যাবে ছাত্রছাত্রীদের উদ্যোগে প্রকাশিত পুস্তিকা *প্রশ্ন-উত্তরে: NRC-NPR-CAA*',
#  ' Unavailable',
#  ' VIRAL Anthem || Manzoor Nahi || Against CAA NRC NPR || LETS MAKE IT VIRAL',
#  ' Unavailable',
#  ' Unavailable',
#  ' Unavailable',
#  ' Unavailable',
#  ' Unavailable',
#  ' বইমেলায় দেখা হলো কমরেড Sumona Choudhuryর সঙ্গে। অসমের করিমগঞ্জের মেয়ে সুমনা। ওর তলোয়ারের মত ধারালো লেখনীর আমি একজন গুণমুগ্ধ পাঠক। অসমে বন্যার সময় #পদক্ষেপের টিম যখন বরপেটায় যায়, সেই সময় থেকেই আলাপ। ও তখন একটার পর একটা ক্ষুরধার লেখা লিখছে আসামে এনআরসি প্রক্রিয়া নিয়ে। আজ সামনাসামনি পেয়ে প্রশ্নে প্রশ্নে ব্যতিব্যস্ত করলাম। তার কিছু ঝলক ধরা রইলো এখানে।',
#  ' নাগরিকত্বের লড়াই: এক বিকল্প রাজনীতির সন্ধানে',
#  ' Unavailable',
#  ' Unavailable',
# ...

# %%
# sh_link=[b for b in text if b.startswith('VM508:104')]
#sh_link=[b for b in text if b.startswith('VM740:104')]
sh_link=[b for b in text if b.startswith('VM513:104')]
sh_link
# Out:
# ['VM513:104 sharedLinkContent \t\t',
#  'VM513:104 sharedLinkContent \t\t',
#  'VM513:104 sharedLinkContent \tUnavailable\t',
#  'VM513:104 sharedLinkContent \t\t',
#  'VM513:104 sharedLinkContent \t\t',
#  'VM513:104 sharedLinkContent \tUnavailable\t',
#  'VM513:104 sharedLinkContent \t\t',
#  'VM513:104 sharedLinkContent \tUnavailable\t',
#  'VM513:104 sharedLinkContent \t\t',
#  'VM513:104 sharedLinkContent \tJANSATTA.COM',
#  'VM513:104 sharedLinkContent \t\t',
#  'VM513:104 sharedLinkContent \tUnavailable\t',
#  'VM513:104 sharedLinkContent \tUnavailable\t',
#  'VM513:104 sharedLinkContent \t\t',
#  'VM513:104 sharedLinkContent \t\t',
#  'VM513:104 sharedLinkContent \tUnavailable\t',
#  'VM513:104 sharedLinkContent \t\t',
#  'VM513:104 sharedLinkContent \t\t',
#  'VM513:104 sharedLinkContent \t\t',
#  'VM513:104 sharedLinkContent \t\t',
#  'VM513:104 sharedLinkContent \tUnavailable\t',
#  'VM513:104 sharedLinkContent \t\t',
#  'VM513:104 sharedLinkContent \tUnavailable\t',
# ...

# %%
# rmov1='VM508:104 sharedLinkContent'
# rmov1='VM740:104 sharedLinkContent'
rmov1='VM513:104 sharedLinkContent'
sharedLink=[]
for x in sh_link:
  x=re.sub(rmov1,'',x)
  x=re.sub(remove2,'',x)
  sharedLink.append(x)

# %%
len(sharedLink)
sharedLink
# Out:
# [' ',
#  ' ',
#  ' Unavailable',
#  ' ',
#  ' ',
#  ' Unavailable',
#  ' ',
#  ' Unavailable',
#  ' ',
#  ' JANSATTA.COM',
#  ' ',
#  ' Unavailable',
#  ' Unavailable',
#  ' ',
#  ' ',
#  ' Unavailable',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' Unavailable',
#  ' ',
#  ' Unavailable',
#  ' ',
#  ' ',
#  ' Unavailable',
#  ' Unavailable',
#  ' ',
#  ' ',
#  ' Unavailable',
#  ' Unavailable',
#  ' Unavailable',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' Unavailable',
#  ' Unavailable',
#  ' ',
#  ' ',
#  " This content isn't available at the moment",
#  ' ',
#  ' Unavailable',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' Unavailable',
#  ' ',
#  ' ',
#  ' Unavailable',
#  ' Unavailable',
#  ' ',
#  ' PEOPLESMAGAZINE.IN',
#  ' GROUNDXERO.IN',
#  ' Unavailable',
#  ' Unavailable',
#  ' YOUTUBE.COM',
#  ' Unavailable',
#  ' ',
#  ' SAT, 18 JAN',
#  ' SAT, 18 JAN',
#  ' Unavailable',
#  ' ',
#  ' ',
#  ' Unavailable',
#  ' ',
#  ' Unavailable',
#  ' ',
#  ' Unavailable',
#  ' ',
# ...

# %%
import pandas as pd

# %%
data={ 'Post_Number': pn,
        'Post_Content': post_Content,
        'Shared_Link_Content': sharedLink,
       'Shared_Post_Content': s}
data=pd.DataFrame(data, columns=['Post_Number','Post_Content','Shared_Link_Content','Shared_Post_Content'])
print(data)
# data.to_excel(r'/content/drive/My Drive/Topic Modeling/Dataset_2.xlsx',index=False,header=True)
data.to_excel(r'/content/drive/My Drive/Topic Modeling/Dataset_5.xlsx',index=False,header=True)
# Out:
#      Post_Number  ...                                Shared_Post_Content
# 0           1632  ...   আজ বইমেলায় No NRC movement আয়োজিত প্রতিবাদী...
# 1           1633  ...                           জানি না এই যুবকের নাম...
# 2           1634  ...                                        Unavailable
# 3           1635  ...   Asaduddin Owaisi blames government for Jamia ...
# 4           1636  ...   We the People of India || #ManzoorNahi || #Pr...
# ..           ...  ...                                                ...
# 369         2001  ...                                        Unavailable
# 370         2002  ...                    আজ গভীর রাতের কেরাল। আশার আলো।❤
# 371         2003  ...   'Aap Democratic tareeke se protest kariye mai...
# 372         2004  ...                                        Unavailable
# 373         2005  ...                                        Unavailable
#
# [374 rows x 4 columns]
